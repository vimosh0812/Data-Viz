# %% [markdown]
# # Task 1 — Hypothesis 4
#
# **Statement:** More difficult questions take longer to answer, but higher-performing students answer them faster than lower-performing students.
#
# **Note:** The CSV has no per-question timestamps; the plots use question scores vs tier and total quiz time vs tier (see code comments in `src/hypotheses_task1.py`).
#
# Run the cell below. Figures: `outputs/h4_difficulty_perf_heatmap.png`, `outputs/h4_time_vs_perf_violin.png`.

# %%
from pathlib import Path
import sys

_root = Path.cwd().resolve()
for _ in range(8):
    if (_root / "src" / "data_io.py").exists():
        break
    _root = _root.parent
else:
    raise FileNotFoundError("Open this notebook from the project folder (contains src/).")
sys.path.insert(0, str(_root))

from src.viz_style import configure_matplotlib
from src.data_io import load_all_quizzes
from src.hypotheses_task1 import run_h4_difficulty_and_time_by_tier

configure_matplotlib()
q1, q2, q3, _ = load_all_quizzes()
OUT = _root / "outputs"
OUT.mkdir(parents=True, exist_ok=True)

run_h4_difficulty_and_time_by_tier(q1, q2, q3, OUT, show=True)
